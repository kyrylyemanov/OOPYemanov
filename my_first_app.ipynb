# %%
from datetime import datetime
name = "Kyryl"
location = "Lviv"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Kyryl start programming at 2025-10-28 21:28:53.127491. Lviv is the best city!
